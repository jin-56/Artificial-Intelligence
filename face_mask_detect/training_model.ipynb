# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %%
train_results = model.train(
    data="data/data.yaml",   
    epochs=20,               
    imgsz=640,
    batch=16,              
    device="cpu",           
    save=True,
    save_period=5
)
# Out:
# Ultralytics 8.3.156  Python-3.12.3 torch-2.7.1+cpu CPU (Intel Core(TM) i5-6200U 2.30GHz)
# ...
