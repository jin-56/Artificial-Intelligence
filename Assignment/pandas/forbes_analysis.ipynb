# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df= pd.read_csv('forbes_2022_billionaires.csv')
df1=df

# %%
df.head(3)
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
#
#            category         source        country       state  ...  \
# 0        Automotive  Tesla, SpaceX  United States       Texas  ...
# 1        Technology         Amazon  United States  Washington  ...
# 2  Fashion & Retail           LVMH         France         NaN  ...
#
#                        organization selfMade gender   birthDate  \
# 0                             Tesla     True      M  1971-06-28
# 1                            Amazon     True      M  1964-01-12
# 2  LVMH Moët Hennessy Louis Vuitton    False      M  1949-03-05
#
#               title philanthropyScore                 residenceMsa  \
# 0               CEO               1.0                          NaN
# ...

# %%
df.tail(3)
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state  ... organization  \
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# 2665     True      M  1965-03-06   NaN               NaN          NaN
# 2666     True      F  1978-07-11   NaN               NaN          NaN
# 2667     True      M  1962-06-15   NaN               NaN          NaN
#
#       numberOfSiblings                                                bio  \
# ...

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
df1.dropna().describe()
# Out:
#               rank       age   finalWorth    year  month  philanthropyScore  \
# count     5.000000   5.00000      5.00000     5.0    5.0           5.000000
# mean    420.800000  67.20000  12980.00000  2022.0    4.0           1.600000
# std     502.923155   6.83374  12745.66593     0.0    0.0           0.547723
# min      37.000000  60.00000   2400.00000  2022.0    4.0           1.000000
# 25%     146.000000  60.00000   6600.00000  2022.0    4.0           1.000000
# 50%     254.000000  70.00000   8400.00000  2022.0    4.0           2.000000
# 75%     375.000000  71.00000  12700.00000  2022.0    4.0           2.000000
# max    1292.000000  75.00000  34800.00000  2022.0    4.0           2.000000
#
#        numberOfSiblings
# count           5.00000
# mean            2.80000
# std             0.83666
# min             2.00000
# 25%             2.00000
# 50%             3.00000
# 75%             3.00000
# max             4.00000

# %%
#count of how many billionares from each country 
g1=df1.groupby("countryOfCitizenship")
g1.count()
# Out:
#                       rank  personName  age  finalWorth  year  month  \
# countryOfCitizenship
# Algeria                  1           1    1           1     1      1
# Argentina                6           6    5           6     6      6
# Australia               46          46   45          46    46     46
# Austria                 11          11   11          11    11     11
# Barbados                 1           1    1           1     1      1
# ...                    ...         ...  ...         ...   ...    ...
# United States          735         735  729         735   735    735
# Uruguay                  2           2    2           2     2      2
# Venezuela                1           1    1           1     1      1
# Vietnam                  7           7    7           7     7      7
# Zimbabwe                 1           1    1           1     1      1
#
#                       category  source  country  state  ...  organization  \
# ...

# %%
#let's see the name of billionares from NEPAL
nep_billionare= df1[df1["country"]=="Nepal"]
nep_billionare
# Out:
#       rank       personName   age  finalWorth  year  month     category  \
# 1948  1929  Binod Chaudhary  66.0      1500.0  2022      4  Diversified
#
#            source country state  ... organization selfMade gender   birthDate  \
# 1948  diversified   Nepal   NaN  ...          NaN    False      M  1955-04-14
#
#      title philanthropyScore residenceMsa  numberOfSiblings  \
# 1948   NaN               NaN          NaN               NaN
#
#                                                     bio  \
# 1948  Binod Chaudhary controls CG Corp Global and is...
#
#                                                   about
# 1948  His late father opened Nepal's first departmen...
#
# [1 rows x 22 columns]

# %%
df1.isnull()
# Out:
#        rank  personName    age  finalWorth   year  month  category  source  \
# 0     False       False  False       False  False  False     False   False
# 1     False       False  False       False  False  False     False   False
# 2     False       False  False       False  False  False     False   False
# 3     False       False  False       False  False  False     False   False
# 4     False       False  False       False  False  False     False   False
# ...     ...         ...    ...         ...    ...    ...       ...     ...
# 2663  False       False  False       False  False  False     False   False
# 2664  False       False  False       False  False  False     False   False
# 2665  False       False  False       False  False  False     False   False
# 2666  False       False  False       False  False  False     False   False
# 2667  False       False  False       False  False  False     False   False
#
# ...

# %%
a=df1[df1["country"]=="United States"].count()
a
# Out:
# rank                    748
# personName              748
# age                     742
# finalWorth              748
# year                    748
# month                   748
# category                748
# source                  748
# country                 748
# state                   748
# city                    748
# countryOfCitizenship    748
# organization            254
# selfMade                748
# gender                  744
# birthDate               742
# title                   280
# philanthropyScore       392
# residenceMsa            639
# numberOfSiblings         21
# bio                     748
# about                   582
# dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# M    2341
# F     311
# Name: count, dtype: int64

# %%
df["country"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', nan, 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Argentina', 'Ireland', 'Bermuda',
#        'Lebanon', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
# ...

# %%
df[df["country"]=="Canada"].gender.value_counts(normalize=True)
# Out:
# gender
# M    0.933333
# F    0.066667
# Name: proportion, dtype: float64
