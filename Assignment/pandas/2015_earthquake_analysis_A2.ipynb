# %%
import pandas as pd
import numpy as np

# %%
df_data=pd.read_csv('nepal-earthquake-severity-index-latest.csv')

# %%
df_data
# Out:
#             P_CODE               VDC_NAME     DISTRICT       REGION  \
# 0     C-BAG-27-031          KathmanduN.P.    Kathmandu      Central
# 1     C-BAG-25-027           LalitpurN.P.     Lalitpur      Central
# 2     C-NAR-35-005         BharatpurN. P.     Chitawan      Central
# 3     C-BAG-26-012     MadhyapurThimiN.P.    Bhaktapur      Central
# 4     C-BAG-27-028                Jorpati    Kathmandu      Central
# ...            ...                    ...          ...          ...
# 3981  F-SET-70-052  Khaptad National Park         Doti  Far-Western
# 3982  M-BHE-58-033   Royal Bardiya Nation      Bardiya  Mid-Western
# 3983  W-LUM-48-075   Royal Chitawan Natio  Nawalparasi      Western
# 3984  W-LUM-49-072    Lumbini Development    Rupandehi      Western
# 3985           NaN                    NaN          NaN          NaN
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# ...

# %%
print(df_data.head())
# Out:
#          P_CODE            VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# 0  C-BAG-27-031       KathmanduN.P.  Kathmandu  Central                2.17
# 1  C-BAG-25-027        LalitpurN.P.   Lalitpur  Central                1.72
# 2  C-NAR-35-005      BharatpurN. P.   Chitawan  Central                2.21
# 3  C-BAG-26-012  MadhyapurThimiN.P.  Bhaktapur  Central                2.45
# 4  C-BAG-27-028             Jorpati  Kathmandu  Central                1.91
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# 0     10.00     8.86     1.82           5.34      4.88              10.0000
# 1      2.26     8.40     0.82           4.61      2.62               5.3707
# 2      1.47     5.38     2.53           3.96      2.34               4.8083
# 3      0.85     8.23     0.89           4.56      2.12               4.3447
# 4      0.87     8.86     1.82           5.34      2.07               4.2407
#
#   Severity category
# 0           Highest
# ...

# %%
df1=df_data

# %%
df1.head(3)
# Out:
#          P_CODE        VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# 0  C-BAG-27-031   KathmanduN.P.  Kathmandu  Central                2.17
# 1  C-BAG-25-027    LalitpurN.P.   Lalitpur  Central                1.72
# 2  C-NAR-35-005  BharatpurN. P.   Chitawan  Central                2.21
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# 0     10.00     8.86     1.82           5.34      4.88              10.0000
# 1      2.26     8.40     0.82           4.61      2.62               5.3707
# 2      1.47     5.38     2.53           3.96      2.34               4.8083
#
#   Severity category
# 0           Highest
# 1           Highest
# 2           Highest

# %%
df1.tail(3)
# Out:
#             P_CODE              VDC_NAME     DISTRICT   REGION  \
# 3983  W-LUM-48-075  Royal Chitawan Natio  Nawalparasi  Western
# 3984  W-LUM-49-072   Lumbini Development    Rupandehi  Western
# 3985           NaN                   NaN          NaN      NaN
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# 3983                0.84       0.0     5.61     3.51           4.56       0.0
# 3984                0.02       0.0     7.81     2.95           5.38       0.0
# 3985                 NaN       NaN      NaN      NaN            NaN       NaN
#
#       Severity Normalized Severity category
# 3983                  0.0            Lowest
# 3984                  0.0            Lowest
# 3985                  NaN               NaN

# %%
#accessing a specific row by index (index location)
print(df1.iloc[2:6]) #rows with indices 1,2,3
# Out:
#          P_CODE            VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# 2  C-NAR-35-005      BharatpurN. P.   Chitawan  Central                2.21
# 3  C-BAG-26-012  MadhyapurThimiN.P.  Bhaktapur  Central                2.45
# 4  C-BAG-27-028             Jorpati  Kathmandu  Central                1.91
# 5  C-BAG-26-003       BhaktapurN.P.  Bhaktapur  Central                1.82
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# 2      1.47     5.38     2.53           3.96      2.34               4.8083
# 3      0.85     8.23     0.89           4.56      2.12               4.3447
# 4      0.87     8.86     1.82           5.34      2.07               4.2407
# 5      0.84     8.23     0.89           4.56      1.91               3.9135
#
#   Severity category
# 2           Highest
# 3           Highest
# 4           Highest
# 5           Highest

# %%
#accessing row by label (name)
print(df1.loc[0])
# Out:
# P_CODE                  C-BAG-27-031
# VDC_NAME               KathmanduN.P.
# DISTRICT                   Kathmandu
# REGION                       Central
# Hazard (Intensity)              2.17
# Exposure                        10.0
# Housing                         8.86
# Poverty                         1.82
# Vulnerability                   5.34
# Severity                        4.88
# Severity Normalized             10.0
# Severity category            Highest
# Name: 0, dtype: object

# %%
#using .loc for slicing (inclusive of end)
most_damaged_areas = df1
#calculating the max severity
Severity_Index = df1.Severity.max()
Severity_Index

most_damaged_areas = df1[df1.Severity == Severity_Index]
most_damaged_areas
# Out:
#          P_CODE       VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# 0  C-BAG-27-031  KathmanduN.P.  Kathmandu  Central                2.17
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# 0      10.0     8.86     1.82           5.34      4.88                 10.0
#
#   Severity category
# 0           Highest

# %%
#filtering based on conditions
print(df1[(df1["Housing"] > 9.9) & (df1["Housing"] < 10)])
# Out:
#             P_CODE             VDC_NAME DISTRICT       REGION  \
# 3522  F-MAH-74-010  DasharathchandaN.P.  Baitadi  Far-Western
# 3593  F-MAH-74-050              Sarmali  Baitadi  Far-Western
# 3608  F-MAH-74-030            Kotpetara  Baitadi  Far-Western
# 3618  F-MAH-74-053           Shikharpur  Baitadi  Far-Western
# 3619  F-MAH-74-016            Dilasaini  Baitadi  Far-Western
# ...            ...                  ...      ...          ...
# 3689  F-MAH-74-051           Shankarpur  Baitadi  Far-Western
# 3690  F-MAH-74-025                  Hat  Baitadi  Far-Western
# 3692  F-MAH-74-059            SreeKedar  Baitadi  Far-Western
# 3693  F-MAH-74-040             Nagarjun  Baitadi  Far-Western
# 3703  F-MAH-74-026               Hatraj  Baitadi  Far-Western
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# 3522                 0.0      0.17     9.94     3.31           6.62       0.0
# ...

# %%
#sorting by the Severity column in descending order
less_damaged_areas = df1.sort_values(by='Severity', ascending=True)
less_damaged_areas=less_damaged_areas.head(10)
less_damaged_areas
# Out:
#             P_CODE             VDC_NAME   DISTRICT       REGION  \
# 3984  W-LUM-49-072  Lumbini Development  Rupandehi      Western
# 3534  F-SET-68-016          Hemantabada    Bajhang  Far-Western
# 3533  M-BHE-57-012              Ganapur      Banke  Mid-Western
# 3532  M-BHE-60-021           KalBhairab    Dailekh  Mid-Western
# 3531  F-SET-68-007            Chaudhari    Bajhang  Far-Western
# 3530  M-BHE-60-036         NauleKatuwal    Dailekh  Mid-Western
# 3529  F-SET-68-033              Maulali    Bajhang  Far-Western
# 3528  F-SET-70-012         Dhirkamandau       Doti  Far-Western
# 3527  M-BHE-57-033             Paraspur      Banke  Mid-Western
# 3526  M-KAR-64-010            Kumalgaun    Kalikot  Mid-Western
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# 3984                0.02      0.00     7.81     2.95           5.38       0.0
# 3534                0.00      0.03     8.74     7.05           7.89       0.0
# ...

# %%
#lets check for unique values in the all the columns
for col in df1:
    print(col)
    print(df1[col].unique())
    print('\n')
# Out:
# P_CODE
# ['C-BAG-27-031' 'C-BAG-25-027' 'C-NAR-35-005' ... 'W-LUM-48-075'
#  'W-LUM-49-072' nan]
#
#
# VDC_NAME
# ['KathmanduN.P.' 'LalitpurN.P.' 'BharatpurN. P.' ...
#  'Royal Bardiya Nation' 'Lumbini Development' nan]
#
#
# DISTRICT
# ['Kathmandu' 'Lalitpur' 'Chitawan' 'Bhaktapur' 'Gorkha' 'Sindhuli'
#  'Kavrepalanchok' 'Makwanpur' 'Nuwakot' 'Tanahu' 'Nawalparasi' 'Dhading'
#  'Dolakha' 'Kaski' 'Sarlahi' 'Mahottari' 'Sindhupalchok' 'Parsa' 'Dhanusa'
#  'Rautahat' 'Ramechhap' 'Bara' 'Rasuwa' 'Lamjung' 'Morang' 'Rupandehi'
#  'Siraha' 'Udayapur' 'Sunsari' 'Kapilbastu' 'Saptari' 'Syangja' 'Palpa'
#  'Okhaldhunga' 'Dang' 'Sankhuwasabha' 'Jhapa' 'Baglung' 'Parbat' 'Banke'
#  'Manang' 'Bhojpur' 'Khotang' 'Solukhumbu' 'Ilam' 'Gulmi' 'Dhankuta'
#  'Pyuthan' 'Taplejung' 'Myagdi' 'Panchthar' 'Rukum' 'Rolpa' 'Salyan'
#  'Mustang' 'Terhathum' 'Jajarkot' 'Dailekh' 'Dolpa' 'Surkhet' 'Jumla'
#  'Bardiya' 'Kalikot' 'Bajura' 'Humla' 'Mugu' 'Doti' 'Achham' 'Bajhang'
# ...

# %%
#as the values are too large so lets discest the data into smaller parts
df1['Severity'].unique()
# Out:
# array([4.88, 2.62, 2.34, 2.12, 2.07, 1.91, 1.89, 1.82, 1.77, 1.69, 1.66,
#        1.65, 1.61, 1.59, 1.57, 1.54, 1.53, 1.48, 1.44, 1.42, 1.41, 1.39,
#        1.35, 1.34, 1.29, 1.28, 1.27, 1.26, 1.24, 1.23, 1.22, 1.21, 1.2 ,
#        1.18, 1.17, 1.16, 1.15, 1.14, 1.13, 1.12, 1.11, 1.1 , 1.09, 1.08,
#        1.07, 1.06, 1.05, 1.04, 1.03, 1.02, 1.01, 1.  , 0.99, 0.98, 0.97,
#        0.96, 0.95, 0.94, 0.93, 0.92, 0.91, 0.9 , 0.89, 0.88, 0.87, 0.86,
#        0.85, 0.84, 0.83, 0.82, 0.81, 0.8 , 0.79, 0.78, 0.77, 0.76, 0.75,
#        0.74, 0.73, 0.72, 0.71, 0.7 , 0.69, 0.68, 0.67, 0.66, 0.65, 0.64,
#        0.63, 0.62, 0.61, 0.6 , 0.59, 0.58, 0.57, 0.56, 0.55, 0.54, 0.53,
#        0.52, 0.51, 0.5 , 0.49, 0.48, 0.47, 0.46, 0.45, 0.44, 0.43, 0.42,
#        0.41, 0.4 , 0.39, 0.38, 0.37, 0.36, 0.35, 0.34, 0.33, 0.32, 0.31,
#        0.3 , 0.29, 0.28, 0.27, 0.26, 0.25, 0.24, 0.23, 0.22, 0.21, 0.2 ,
#        0.19, 0.18, 0.17, 0.16, 0.15, 0.14, 0.13, 0.12, 0.11, 0.1 , 0.09,
# ...

# %%
# calculation of mean of all the columns in the data
#mean of all the column of dataframe

print('By default mean will calculate column-wise:')
print(df1.mean(numeric_only=True))


print('\n Mean of all row-wise without null case:')
print(df1.mean(axis=1, skipna=True, numeric_only=True)) #axis 1 is row and axis 0 is column, skipna is used to skip the null values
# Out:
# By default mean will calculate column-wise:
# Hazard (Intensity)     0.320537
# Exposure               0.067493
# Housing                5.706522
# Poverty                5.481854
# Vulnerability          5.594635
# Severity               0.248720
# Severity Normalized    0.510221
# dtype: float64
#
#  Mean of all row-wise without null case:
# 0       6.152857
# 1       3.685814
# 2       3.242614
# 3       3.349243
# 4       3.587243
#           ...
# 3981    3.650000
# 3982    2.027143
# 3983    2.074286
# 3984    2.308571
# 3985         NaN
# Length: 3986, dtype: float64

# %%
#lets calculate specific mean for every columns
print('Mean of all the columns in the data:')
print('Exposure:',df1.Exposure.mean())
print('Housing:',df1.Housing.mean()) 
print('Poverty:',df1.Poverty.mean())
print('Vulnerability:',df1.Vulnerability.mean())
print('Severity:',df1.Severity.mean())
# Out:
# Mean of all the columns in the data:
# Exposure: 0.06749309912170641
# Housing: 5.7065219573400245
# Poverty: 5.481854454203263
# Vulnerability: 5.594634880803012
# Severity: 0.24872020075282308

# %%
df1.columns
# Out:
# Index(['P_CODE', 'VDC_NAME', 'DISTRICT', 'REGION', 'Hazard (Intensity)',
#        'Exposure', 'Housing', 'Poverty', 'Vulnerability', 'Severity',
#        'Severity Normalized', 'Severity category'],
#       dtype='object')

# %%
#let's drop some columns to make the data more readable
df1.drop(['Severity Normalized','Severity category'],axis=1)
# Out:
#             P_CODE               VDC_NAME     DISTRICT       REGION  \
# 0     C-BAG-27-031          KathmanduN.P.    Kathmandu      Central
# 1     C-BAG-25-027           LalitpurN.P.     Lalitpur      Central
# 2     C-NAR-35-005         BharatpurN. P.     Chitawan      Central
# 3     C-BAG-26-012     MadhyapurThimiN.P.    Bhaktapur      Central
# 4     C-BAG-27-028                Jorpati    Kathmandu      Central
# ...            ...                    ...          ...          ...
# 3981  F-SET-70-052  Khaptad National Park         Doti  Far-Western
# 3982  M-BHE-58-033   Royal Bardiya Nation      Bardiya  Mid-Western
# 3983  W-LUM-48-075   Royal Chitawan Natio  Nawalparasi      Western
# 3984  W-LUM-49-072    Lumbini Development    Rupandehi      Western
# 3985           NaN                    NaN          NaN          NaN
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity
# ...

# %%
df3=df1

# %%
df3.dropna()
# Out:
#             P_CODE               VDC_NAME     DISTRICT       REGION  \
# 0     C-BAG-27-031          KathmanduN.P.    Kathmandu      Central
# 1     C-BAG-25-027           LalitpurN.P.     Lalitpur      Central
# 2     C-NAR-35-005         BharatpurN. P.     Chitawan      Central
# 3     C-BAG-26-012     MadhyapurThimiN.P.    Bhaktapur      Central
# 4     C-BAG-27-028                Jorpati    Kathmandu      Central
# ...            ...                    ...          ...          ...
# 3980  F-SET-69-076   Khaptad National Par       Achham  Far-Western
# 3981  F-SET-70-052  Khaptad National Park         Doti  Far-Western
# 3982  M-BHE-58-033   Royal Bardiya Nation      Bardiya  Mid-Western
# 3983  W-LUM-48-075   Royal Chitawan Natio  Nawalparasi      Western
# 3984  W-LUM-49-072    Lumbini Development    Rupandehi      Western
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# ...

# %%
#let's analyze data of kathmandu only
ktm_data= df1[df1['DISTRICT'] == 'Kathmandu']
print(ktm_data)
# Out:
#            P_CODE             VDC_NAME   DISTRICT   REGION  \
# 0    C-BAG-27-031        KathmanduN.P.  Kathmandu  Central
# 4    C-BAG-27-028              Jorpati  Kathmandu  Central
# 9    C-BAG-27-033         KirtipurN.P.  Kathmandu  Central
# 10   C-BAG-27-022             Gonggabu  Kathmandu  Central
# 11   C-BAG-27-030                Kapan  Kathmandu  Central
# 19   C-BAG-27-016              Dhapasi  Kathmandu  Central
# 20   C-BAG-27-023             Gothatar  Kathmandu  Central
# 24   C-BAG-27-038             Manmaiju  Kathmandu  Central
# 38   C-BAG-27-037             Mahankal  Kathmandu  Central
# 51   C-BAG-27-024        IchangNarayan  Kathmandu  Central
# 59   C-BAG-27-036         Mahadevathan  Kathmandu  Central
# 66   C-BAG-27-008        Budanilkantha  Kathmandu  Central
# 72   C-BAG-27-052            Sitapaila  Kathmandu  Central
# 81   C-BAG-27-056              Thankot  Kathmandu  Central
# 82   C-BAG-27-040              Mulpani  Kathmandu  Central
# ...

# %%
#lte's assume that highest range of poverty hit be from 2 to 10 
#and lets obtain the data 
df4=df1
df4.dropna()
df4=df1[(df1['Poverty']>=2) & (df1['Poverty']<=10)]
df4
# Out:
#             P_CODE               VDC_NAME        DISTRICT       REGION  \
# 2     C-NAR-35-005         BharatpurN. P.        Chitawan      Central
# 6     W-GAN-36-050     PrithbinarayanN.P.          Gorkha      Western
# 7     C-JAN-20-025           KamalamiN.P.        Sindhuli      Central
# 8     C-JAN-20-026              Kapilakot        Sindhuli      Central
# 12    C-BAG-24-065           PanautiN. P.  Kavrepalanchok      Central
# ...            ...                    ...             ...          ...
# 3980  F-SET-69-076   Khaptad National Par          Achham  Far-Western
# 3981  F-SET-70-052  Khaptad National Park            Doti  Far-Western
# 3982  M-BHE-58-033   Royal Bardiya Nation         Bardiya  Mid-Western
# 3983  W-LUM-48-075   Royal Chitawan Natio     Nawalparasi      Western
# 3984  W-LUM-49-072    Lumbini Development       Rupandehi      Western
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# ...

# %%
df4
# Out:
#             P_CODE               VDC_NAME        DISTRICT       REGION  \
# 2     C-NAR-35-005         BharatpurN. P.        Chitawan      Central
# 6     W-GAN-36-050     PrithbinarayanN.P.          Gorkha      Western
# 7     C-JAN-20-025           KamalamiN.P.        Sindhuli      Central
# 8     C-JAN-20-026              Kapilakot        Sindhuli      Central
# 12    C-BAG-24-065           PanautiN. P.  Kavrepalanchok      Central
# ...            ...                    ...             ...          ...
# 3980  F-SET-69-076   Khaptad National Par          Achham  Far-Western
# 3981  F-SET-70-052  Khaptad National Park            Doti  Far-Western
# 3982  M-BHE-58-033   Royal Bardiya Nation         Bardiya  Mid-Western
# 3983  W-LUM-48-075   Royal Chitawan Natio     Nawalparasi      Western
# 3984  W-LUM-49-072    Lumbini Development       Rupandehi      Western
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# ...

# %%
# Count the null values in each column
null= df_data.P_CODE.isnull().sum()
print(null)

# now for percentage of null values
print(df_data.shape[0])
null_percent = (null / df_data.shape[0]) * 100
null_percent
# Out:
# 1
# 3986
# 0.025087807325639738

# %%
#let's analyze according to the poverty hit
max_poverty = df1['Poverty'].max()
print("Highest Poverty Hit:", max_poverty)

district_highest_hit = df1.loc[df1['Poverty'] == max_poverty, 'DISTRICT'].iloc[0]
print("District Name of Highest Hit:", district_highest_hit)
# Out:
# Highest Poverty Hit: 10.0
# District Name of Highest Hit: Humla

# %%
df3.sort_values('Poverty',ascending=False)
# Out:
#             P_CODE        VDC_NAME DISTRICT       REGION  Hazard (Intensity)  \
# 3289  M-KAR-66-007           Hepka    Humla  Mid-Western                0.00
# 3691  M-KAR-66-018           Muchu    Humla  Mid-Western                0.00
# 3300  M-KAR-66-016        Melchham    Humla  Mid-Western                0.00
# 3298  M-KAR-66-022      Saya(Sama)    Humla  Mid-Western                0.00
# 3297  M-KAR-66-001       Baraigaun    Humla  Mid-Western                0.00
# ...            ...             ...      ...          ...                 ...
# 1783  W-GAN-40-045          Bhalam    Kaski      Western                0.05
# 2247  W-GAN-40-004  Bhadauretamagi    Kaski      Western                0.01
# 1800  W-GAN-40-014        Hansapur    Kaski      Western                0.04
# 1892  W-GAN-40-040      Sardikhola    Kaski      Western                0.03
# 3985           NaN             NaN      NaN          NaN                 NaN
#
# ...

# %%
df4=df_data.dropna()
HIN=df4.sort_values('Hazard (Intensity)',ascending=False)
HIN
# Out:
#             P_CODE        VDC_NAME        DISTRICT       REGION  \
# 13    C-JAN-20-034    Mahadevsthan        Sindhuli      Central
# 23    C-JAN-20-013    Dadiguranshe        Sindhuli      Central
# 8     C-JAN-20-026       Kapilakot        Sindhuli      Central
# 14    C-JAN-20-024  Kalpabrishykha        Sindhuli      Central
# 48    C-BAG-24-032          Gokule  Kavrepalanchok      Central
# ...            ...             ...             ...          ...
# 2800  W-LUM-46-031         Dirbung           Gulmi      Western
# 2799  E-KOS-10-032        Khairang         Bhojpur      Eastern
# 2798  W-LUM-46-009       Arlangkot           Gulmi      Western
# 2797  E-KOS-08-028           Solma       Terhathum      Eastern
# 2878  M-RAP-54-002      AathbisKot           Rukum  Mid-Western
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# 13                 10.00      0.07     5.19     6.55           5.87      1.61
# ...

# %%
D=df3.groupby(['DISTRICT','Poverty'])
D.first()
# Out:
#                             P_CODE             VDC_NAME       REGION  \
# DISTRICT     Poverty
# Achham       9.21     F-SET-69-047            Mangalsen  Far-Western
# Arghakhanchi 3.32     W-LUM-51-036         Sandhikharka      Western
# Baglung      4.76     W-DHA-45-006          BaglungN.P.      Western
# Baitadi      3.31     F-MAH-74-010  DasharathchandaN.P.  Far-Western
# Bajhang      7.05     F-SET-68-022            Khiratadi  Far-Western
# ...                            ...                  ...          ...
# Syangja      4.88     W-GAN-39-044      PutalibazarN.P.      Western
# Tanahu       4.04     W-GAN-38-001         Aabukhaireni      Western
# Taplejung    3.03     E-MEC-01-032            Phungling      Eastern
# Terhathum    5.04     E-KOS-08-015            Myanglung      Eastern
# Udayapur     4.04     E-SAG-14-043         TriyugaN. P.      Eastern
#
#                       Hazard (Intensity)  Exposure  Housing  Vulnerability  \
# DISTRICT     Poverty
# ...

# %%
LP=df1.groupby('DISTRICT')
a=LP.get_group('Lalitpur')
a.iloc[0:5]
# Out:
#           P_CODE      VDC_NAME  DISTRICT   REGION  Hazard (Intensity)  \
# 1   C-BAG-25-027  LalitpurN.P.  Lalitpur  Central                1.72
# 27  C-BAG-25-023        Imadol  Lalitpur  Central                1.87
# 32  C-BAG-25-009     Chapagaun  Lalitpur  Central                2.58
# 60  C-BAG-25-029          Lele  Lalitpur  Central                3.18
# 69  C-BAG-25-035        Sainbu  Lalitpur  Central                1.27
#
#     Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# 1       2.26      8.4     0.82           4.61      2.62               5.3707
# 27      0.28      8.4     0.82           4.61      1.34               2.7515
# 32      0.17      8.4     0.82           4.61      1.26               2.5840
# 60      0.09      8.4     0.82           4.61      1.08               2.2179
# 69      0.20      8.4     0.82           4.61      1.06               2.1725
#
#    Severity category
# 1            Highest
# 27              High
# ...

# %%
LP=df1.groupby('VDC_NAME')
LP.get_group('Godawari')
# Out:
#             P_CODE  VDC_NAME  DISTRICT       REGION  Hazard (Intensity)  \
# 90    C-BAG-25-019  Godawari  Lalitpur      Central                2.86
# 3778  F-SET-71-015  Godawari   Kailali  Far-Western                0.00
#
#       Exposure  Housing  Poverty  Vulnerability  Severity  \
# 90        0.08     8.40     0.82           4.61      1.01
# 3778      0.16     4.41     3.97           4.19      0.00
#
#       Severity Normalized Severity category
# 90                 2.0662              High
# 3778               0.0000            Lowest

# %%
D=df3.groupby(['DISTRICT','VDC_NAME'])
D.first()
# Out:
#                              P_CODE       REGION  Hazard (Intensity)  \
# DISTRICT VDC_NAME
# Achham   Babala        F-SET-69-001  Far-Western                0.00
#          Baijanath     F-SET-69-002  Far-Western                0.00
#          Bannatoli     F-SET-69-003  Far-Western                0.00
#          Baradadevi    F-SET-69-004  Far-Western                0.00
#          Basti         F-SET-69-005  Far-Western                0.00
# ...                             ...          ...                 ...
# Udayapur Thoksila      E-SAG-14-041      Eastern                0.01
#          Tribeni       E-SAG-14-042      Eastern                0.06
#          TriyugaN. P.  E-SAG-14-043      Eastern                0.02
#          Valayadanda   E-SAG-14-044      Eastern                0.01
#          Yayankhu      E-SAG-14-045      Eastern                0.01
#
#                        Exposure  Housing  Poverty  Vulnerability  Severity  \
# DISTRICT VDC_NAME
# ...

# %%
# D=df3.groupby(['DISTRICT','VDC_NAME'])
ktm = df3[df3['DISTRICT'] == 'Kathmandu']
K = ktm.groupby('VDC_NAME')
K.first()
# Out:
#                            P_CODE   DISTRICT   REGION  Hazard (Intensity)  \
# VDC_NAME
# Aalapot              C-BAG-27-001  Kathmandu  Central                1.34
# Baad Bhanjyang       C-BAG-27-002  Kathmandu  Central                1.44
# Bajrayogini          C-BAG-27-003  Kathmandu  Central                1.30
# Balambu              C-BAG-27-004  Kathmandu  Central                0.91
# Baluwa               C-BAG-27-005  Kathmandu  Central                1.10
# Bhadrabas            C-BAG-27-006  Kathmandu  Central                1.44
# Bhimdhunga           C-BAG-27-007  Kathmandu  Central                1.07
# Budanilkantha        C-BAG-27-008  Kathmandu  Central                1.42
# Chalnakhel           C-BAG-27-009  Kathmandu  Central                0.83
# ChapaliBhadrakali    C-BAG-27-010  Kathmandu  Central                1.14
# Chhaimale            C-BAG-27-011  Kathmandu  Central                3.09
# ...
